# %%
import pandas as pd
import zipfile
import os

# %%
curDir = os.getcwd()
file_path = curDir + '/Data_files/'

# %% [markdown]
# ## Explore data analysis of Statistics Canada file ##
# population source data from
# https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/prof/details/page_Download-Telecharger.cfm?Lang=E&Tab=1&Geo1=CMACA&Code1=535&Geo2=PR&Code2=35&Data=Count&SearchText=Caledon%20East&SearchType=Begins&SearchPR=01&B1=Population&TABID=1

# %% [markdown]
# Data File Definitions / Footnotes
#
# Profile of Forward Sortation Areas (2247)
#
# Member
# 1. Population, 2016 (1)
# 2. Population, 2011 (2)
# 3. Population percentage change, 2011 to 2016
# 4. Total private dwellings (3)
# 5. Private dwellings occupied by usual residents (4)
# 6. Population density per square kilometre
# 7. Land area in square kilometres
# 8. Total - Age groups and average age of the population - 100% data (5)
# 9.   0 to 14 years
# 10.     0 to 4 years
# 11.     5 to 9 years
# 12.     10 to 14 years
# 13.   15 to 64 years
# 14.     15 to 19 years
# 15.     20 to 24 years
# 16.     25 to 29 years
# 17.     30 to 34 years
# 18.     35 to 39 years
# 19.     40 to 44 years
# 20.     45 to 49 years
# 21.     50 to 54 years
# 22.     55 to 59 years
# 23.     60 to 64 years
# 24.   65 years and over
# 25.     65 to 69 years
# 26.     70 to 74 years
# 27.     75 to 79 years
# 28.     80 to 84 years
# 29.     85 years and over
# 30.       85 to 89 years
# 31.       90 to 94 years
# 32.       95 to 99 years
# 33.       100 years and over
# 34. Total - Distribution (%) of the population by broad age groups - 100% data
# 35.   0 to 14 years
# 36.   15 to 64 years
# 37.   65 years and over
# 38.     85 years and over
# 39. Average age of the population
# 40. Median age of the population (6)
# 41. Total - Occupied private dwellings by structural type of dwelling - 100% data (7)
# 42.   Single-detached house
# 43.   Apartment in a building that has five or more storeys
# 44.   Other attached dwelling (8)
# 45.     Semi-detached house
# 46.     Row house
# 47.     Apartment or flat in a duplex
# 48.     Apartment in a building that has fewer than five storeys
# 49.     Other single-attached house
# 50.   Movable dwelling (9)
# 51. Total - Private households by household size - 100% data (10)
# 52.   1 person
# 53.   2 persons
# 54.   3 persons
# 55.   4 persons
# 56.   5 or more persons
# 57. Number of persons in private households
# 58. Average household size
# 59. Total - Marital status for the population aged 15 years and over - 100% data (11)
# 60.   Married or living common law
# 61.     Married
# 62.     Living common law
# 63.   Not married and not living common law
# 64.     Never married
# 65.     Separated
# 66.     Divorced
# 67.     Widowed
# 68. Total - Census families in private households by family size - 100% data (12)
# 69.   2 persons
# 70.   3 persons
# 71.   4 persons
# 72.   5 or more persons
# 73. Average size of census families
# 74. Total number of census families in private households - 100% data
# 75.   Total couple families
# 76.     Married couples
# 77.     Common-law couples
# 78.   Total lone-parent families by sex of parent
# 79.     Female parent
# 80.     Male parent
# 81. Total - Couple census families in private households - 100% data
# 82.   Couples without children
# 83.   Couples with children
# 84.     1 child
# 85.     2 children
# 86.     3 or more children
# 87. Total - Lone-parent census families in private households - 100% data
# 88.   1 child
# 89.   2 children
# 90.   3 or more children
# 91. Total - Persons not in census families in private households - 100% data
# 92. Total - Private households by household type - 100% data (13)
# 93.   One-census-family households
# 94.     Without children in a census family (14)
# 95.     With children in a census family (15)
# 96.   Multiple-census-family households
# 97.   Non-census-family households
# 98.     One-person households
# 99.     Two-or-more person non-census-family households
# 100. Total - Knowledge of official languages for the total population excluding institutional residents - 100% data (16)

# %%
df_GeoInfo = pd.read_csv(file_path + '98-401-X2016046_English_CSV_data.csv')

# %%
df_GeoInfo.head()
# Out:
#    CENSUS_YEAR GEO_CODE (POR)  GEO_LEVEL GEO_NAME  GNR  GNR_LF  \
# 0         2016             01          0   Canada  4.0     5.1
# 1         2016             01          0   Canada  4.0     5.1
# 2         2016             01          0   Canada  4.0     5.1
# 3         2016             01          0   Canada  4.0     5.1
# 4         2016             01          0   Canada  4.0     5.1
#
#    DATA_QUALITY_FLAG ALT_GEO_CODE  \
# 0              20000           01
# 1              20000           01
# 2              20000           01
# 3              20000           01
# 4              20000           01
#
#   DIM: Profile of Forward Sortation Areas (2247)  \
# 0                               Population, 2016
# 1                               Population, 2011
# 2     Population percentage change, 2011 to 2016
# 3                        Total private dwellings
# 4  Private dwellings occupied by usual residents
#
#    Member ID: Profile of Forward Sortation Areas (2247)  \
# ...

# %%
df_GeoInfo.tail()
# Out:
#          CENSUS_YEAR GEO_CODE (POR)  GEO_LEVEL GEO_NAME  GNR  GNR_LF  \
# 3689569         2016            Y1A          2      Y1A  5.3     5.7
# 3689570         2016            Y1A          2      Y1A  5.3     5.7
# 3689571         2016            Y1A          2      Y1A  5.3     5.7
# 3689572         2016            Y1A          2      Y1A  5.3     5.7
# 3689573         2016            Y1A          2      Y1A  5.3     5.7
#
#          DATA_QUALITY_FLAG ALT_GEO_CODE  \
# 3689569                101        01Y1A
# 3689570                101        01Y1A
# 3689571                101        01Y1A
# 3689572                101        01Y1A
# 3689573                101        01Y1A
#
#         DIM: Profile of Forward Sortation Areas (2247)  \
# 3689569                                       Migrants
# 3689570                              Internal migrants
# 3689571                       Intraprovincial migrants
# 3689572                       Interprovincial migrants
# ...

# %%
df_GeoInfo.shape
# Out:
# (3689574, 14)

# %%
df_GeoInfo.dtypes
# Out:
# CENSUS_YEAR                                               int64
# GEO_CODE (POR)                                           object
# GEO_LEVEL                                                 int64
# GEO_NAME                                                 object
# GNR                                                     float64
# GNR_LF                                                  float64
# DATA_QUALITY_FLAG                                         int64
# ALT_GEO_CODE                                             object
# DIM: Profile of Forward Sortation Areas (2247)           object
# Member ID: Profile of Forward Sortation Areas (2247)      int64
# Notes: Profile of Forward Sortation Areas (2247)        float64
# Dim: Sex (3): Member ID: [1]: Total - Sex                object
# Dim: Sex (3): Member ID: [2]: Male                       object
# Dim: Sex (3): Member ID: [3]: Female                     object
# dtype: object

# %%
df_GeoInfo.describe()
# Out:
#        CENSUS_YEAR     GEO_LEVEL           GNR        GNR_LF  \
# count    3689574.0  3.689574e+06  3.642387e+06  3.642387e+06
# mean        2016.0  1.998782e+00  4.121468e+00  5.239358e+00
# std            0.0  4.934137e-02  2.515521e+00  2.805267e+00
# min         2016.0  0.000000e+00  0.000000e+00  0.000000e+00
# 25%         2016.0  2.000000e+00  2.900000e+00  3.700000e+00
# 50%         2016.0  2.000000e+00  3.700000e+00  4.800000e+00
# 75%         2016.0  2.000000e+00  4.700000e+00  6.200000e+00
# max         2016.0  2.000000e+00  4.670000e+01  5.850000e+01
#
#        DATA_QUALITY_FLAG  \
# count       3.689574e+06
# mean        1.853983e+02
# std         1.246792e+03
# min         0.000000e+00
# 25%         0.000000e+00
# 50%         0.000000e+00
# 75%         0.000000e+00
# max         2.000000e+04
#
#        Member ID: Profile of Forward Sortation Areas (2247)  \
# count                                       3.689574e+06
# ...

# %%
df_GeoInfo['GEO_CODE (POR)'].unique()
# Out:
# array(['01', 'A0A', 'A0B', ..., 'Y0A', 'Y0B', 'Y1A'], dtype=object)

# %%
df_GeoInfo['GEO_LEVEL'].unique()
# Out:
# array([0, 2])

# %% [markdown]
# *** total population szie ***

# %%
df_pop_total = df_GeoInfo[df_GeoInfo['Member ID: Profile of Forward Sortation Areas (2247)']==1].reset_index()
df_pop_total.shape
# Out:
# (1642, 15)

# %%
df_pop_total.head()
# Out:
#    index  CENSUS_YEAR GEO_CODE (POR)  GEO_LEVEL GEO_NAME  GNR  GNR_LF  \
# 0      0         2016             01          0   Canada  4.0     5.1
# 1   2247         2016            A0A          2      A0A  4.2     9.1
# 2   4494         2016            A0B          2      A0B  4.1    10.1
# 3   6741         2016            A0C          2      A0C  4.1     8.6
# 4   8988         2016            A0E          2      A0E  4.2     8.1
#
#    DATA_QUALITY_FLAG ALT_GEO_CODE  \
# 0              20000           01
# 1                  0        01A0A
# 2                 10        01A0B
# 3                  0        01A0C
# 4                  0        01A0E
#
#   DIM: Profile of Forward Sortation Areas (2247)  \
# 0                               Population, 2016
# 1                               Population, 2016
# 2                               Population, 2016
# 3                               Population, 2016
# 4                               Population, 2016
#
# ...

# %% [markdown]
# *** children age 0-14 population size ***

# %%
df_pop_child = df_GeoInfo[df_GeoInfo['Member ID: Profile of Forward Sortation Areas (2247)']==9].reset_index()
df_pop_child.shape
# Out:
# (1642, 15)

# %%
df_pop_child.head()
# Out:
#    index  CENSUS_YEAR GEO_CODE (POR)  GEO_LEVEL GEO_NAME  GNR  GNR_LF  \
# 0      8         2016             01          0   Canada  4.0     5.1
# 1   2255         2016            A0A          2      A0A  4.2     9.1
# 2   4502         2016            A0B          2      A0B  4.1    10.1
# 3   6749         2016            A0C          2      A0C  4.1     8.6
# 4   8996         2016            A0E          2      A0E  4.2     8.1
#
#    DATA_QUALITY_FLAG ALT_GEO_CODE  \
# 0              20000           01
# 1                  0        01A0A
# 2                 10        01A0B
# 3                  0        01A0C
# 4                  0        01A0E
#
#   DIM: Profile of Forward Sortation Areas (2247)  \
# 0                                  0 to 14 years
# 1                                  0 to 14 years
# 2                                  0 to 14 years
# 3                                  0 to 14 years
# 4                                  0 to 14 years
#
# ...

# %% [markdown]
# ## Import Toronto Postal codes ##

# %%
import requests
import lxml.html as lh
import pandas as pd
from bs4 import BeautifulSoup

# %%
# wiki page url
Toronto_postal_code_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# request wikipage 
Toronto_raw_page = requests.get(Toronto_postal_code_link)
bs=BeautifulSoup(Toronto_raw_page.text,"lxml")
table_body=bs.find('tbody')

# tabel part
rows = table_body.find_all('tr')
heads = table_body.find_all('th')

# %%
heads=list(heads)

# %%
def clean(text):
    '''clean table header for column names'''
    text=text.replace('<th>','').replace("</th>",'').replace("\n",'')
    return text

col_name = [clean(str(w)) for w in heads]
col_name
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %%
df=pd.DataFrame(columns=col_name)
for i,row in enumerate(rows[1:]):
    cols=row.find_all('td')
    cols=[x.text.strip() for x in cols]
    df.loc[i] = cols

# %%
df['Borough'].unique()
# Out:
# array(['Not assigned', 'North York', 'Downtown Toronto', "Queen's Park",
#        'Etobicoke', 'Scarborough', 'East York', 'York', 'East Toronto',
#        'West Toronto', 'Central Toronto', 'Mississauga'], dtype=object)

# %%
df1=df[~df['Borough'].isin(['Not assigned',''])]

# %%
df1.shape
# Out:
# (212, 3)

# %%
df2=df1.groupby(['Postcode','Borough'])['Neighbourhood'].agg(lambda x: ','.join(x)).reset_index()

# %%
df2.loc[df2['Neighbourhood']=='Not assigned',['Neighbourhood']]=df2['Borough']

# %%
df2.shape
# Out:
# (103, 3)

# %%
df2_pop_child=df2.merge(df_pop_child, left_on=['Postcode'],right_on=['GEO_NAME'],how="left")
df2_pop_child.head()
# Out:
#   Postcode      Borough                         Neighbourhood      index  \
# 0      M1B  Scarborough                         Rouge,Malvern  2011073.0
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  2013320.0
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill  2015567.0
# 3      M1G  Scarborough                                Woburn  2017814.0
# 4      M1H  Scarborough                             Cedarbrae  2020061.0
#
#    CENSUS_YEAR GEO_CODE (POR)  GEO_LEVEL GEO_NAME  GNR  GNR_LF  \
# 0       2016.0            M1B        2.0      M1B  2.7     4.9
# 1       2016.0            M1C        2.0      M1C  2.8     3.7
# 2       2016.0            M1E        2.0      M1E  4.0     4.4
# 3       2016.0            M1G        2.0      M1G  3.3     4.9
# 4       2016.0            M1H        2.0      M1H  3.4     6.2
#
#    DATA_QUALITY_FLAG ALT_GEO_CODE  \
# 0                0.0        01M1B
# 1                0.0        01M1C
# 2                0.0        01M1E
# ...

# %%
df3 = df2_pop_child[['Postcode','Borough','Neighbourhood','Dim: Sex (3): Member ID: [1]: Total - Sex']]

# %%
df3 = df3.rename({'Dim: Sex (3): Member ID: [1]: Total - Sex' : 'Child age 0-14 Pop Size'},axis='columns')
df3
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# # Get the latitude and the longitude coordinates of each neighborhood #
#
# link to a csv file that has the geographical coordinates of each postal code: http://cocl.us/Geospatial_data

# %%
csv_zip = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
csv_zip.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
csv_zip.rename(columns={'Postal Code' : 'Postcode'},inplace=True)
csv_zip.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
df4=df3.merge(csv_zip, on=['Postcode'],how="left")

# %%
df4.tail()
# Out:
#     Postcode    Borough                                      Neighbourhood  \
# 98       M9N       York                                             Weston
# 99       M9P  Etobicoke                                          Westmount
# 100      M9R  Etobicoke  Kingsview Village,Martin Grove Gardens,Richvie...
# 101      M9V  Etobicoke  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 102      M9W  Etobicoke                                          Northwest
#
#     Child age 0-14 Pop Size   Latitude  Longitude
# 98                     4345  43.706876 -79.518188
# 99                     3140  43.696319 -79.532242
# 100                    6075  43.688905 -79.554724
# 101                   10730  43.739416 -79.588437
# 102                    6595  43.706748 -79.594054

# %%
df4.to_csv(file_path + 'df_toronto_out.csv')

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.0.2p             |       h470a237_1         3.1 MB  conda-forge
#     certifi-2018.10.15         |        py36_1000         138 KB  conda-forge
#     geopy-1.17.0               |             py_0          49 KB  conda-forge
#     ca-certificates-2018.10.15 |       ha4d7672_0         135 KB  conda-forge
#     conda-4.5.11               |        py36_1000         651 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
CLIENT_ID = 'VBSBYNY2VBFL0HR4KT0ACIIXSHLZDSFT3HIRAWSW5WO4OXBW' # your Foursquare ID
CLIENT_SECRET = 'UGRKTBG241NH0K2ERHHCY3S1I3T3W1YOANUYBQW5ANU13WQH' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 30

# %%
geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode('Toronto, ON')
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
df_Toronto = pd.read_csv(file_path + 'df_out.csv')

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, Borough, Postcode in zip(df_Toronto['Latitude'], df_Toronto['Longitude'], df_Toronto['Borough'],df_Toronto['Postcode']):
    label = Borough + ' (' + Postcode + ')'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
CLIENT_ID = 'VBSBYNY2VBFL0HR4KT0ACIIXSHLZDSFT3HIRAWSW5WO4OXBW' # your Foursquare ID
CLIENT_SECRET = 'UGRKTBG241NH0K2ERHHCY3S1I3T3W1YOANUYBQW5ANU13WQH' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 30
radius = 20000

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %%
search_query = "Kumon"

print(search_query + ' .... OK!')
# Out:
# Kumon .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=VBSBYNY2VBFL0HR4KT0ACIIXSHLZDSFT3HIRAWSW5WO4OXBW&client_secret=UGRKTBG241NH0K2ERHHCY3S1I3T3W1YOANUYBQW5ANU13WQH&ll=43.653963,-79.387207&v=20180605&query=Kumon&radius=20000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.tail()
# Out:
#                                            categories  hasPerk  \
# 22  [{'id': '4bf58dd8d48988d1ab941735', 'name': 'S...    False
# 23  [{'id': '4bf58dd8d48988d13b941735', 'name': 'S...    False
# 24  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 25                                                 []    False
# 26  [{'id': '4bf58dd8d48988d1ab941735', 'name': 'S...    False
#
#                           id                  location.address location.cc  \
# 22  510fd103e4b0d7e127541659                               NaN          CA
# 23  4d4d6436b887a1cd3e44bba0  377 Burnhamthorpe Rd. E. Unit 14          CA
# 24  4cb9dc2e035d236add93d64e               640 Applewood Cres.          CA
# 25  4d657b8d072a6ea877d3fd4d          4218-4234 Lawrence Ave E          CA
# 26  4e31e3e9d22dc6a915324223                9206 Leslie Street          CA
#
#     location.city location.country location.crossStreet  location.distance  \
# ...

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                              name                    categories  \
# 0                 Kumon Chinatown                        School
# 1                           kumon                Student Center
# 2     Kumon Math & Reading Centre                        Office
# 3            Leaside Kumon Centre  General College & University
# 4                           kumon                Student Center
# 5     Kumon Math & Reading Centre                        Office
# 6                  Kumon Danforth   Professional & Other Places
# 7     Kumon Math & Reading Centre                        Office
# 8                           Kumon                  Trade School
# 9                           Kumon                Student Center
# 10                          Kumon                Student Center
# 11                          Kumon                Student Center
# 12      Kumon - Danforth/ Coxwell                Student Center
# 13                          Kumon                          None
# ...

# %%
dataframe_filtered.name
# Out:
# 0                   Kumon Chinatown
# 1                             kumon
# 2       Kumon Math & Reading Centre
# 3              Leaside Kumon Centre
# 4                             kumon
# 5       Kumon Math & Reading Centre
# 6                    Kumon Danforth
# 7       Kumon Math & Reading Centre
# 8                             Kumon
# 9                             Kumon
# 10                            Kumon
# 11                            Kumon
# 12        Kumon - Danforth/ Coxwell
# 13                            Kumon
# 14      Kumon Math & Reading Centre
# 15              Kumon - Forest Hill
# 16                            Kumon
# 17                            Kumon
# 18    Kumon Eglinton Ave At Brimley
# 19                 Westbourne Kumon
# 20       Kumon (scarborough centre)
# 21          Royal York Kumon Centre
# 22                            Kumon
# 23      Kumon Math & Reading Centre
# 24                Kumon Canada Inc.
# 25                        Kumon Ctr
# ...

# %%
# save dataset into csv
dataframe_filtered.to_csv(file_path + 'kumon_out.csv')
